# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn 
df = pd.read_csv("train.csv")
df
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1             13.168425                       9.447662
# 1          csid_2             17.092979                       7.329056
# 2          csid_3             17.505334                       5.143676
# 3          csid_4             31.423381                       4.917740
# 4          csid_5             11.909502                       4.237073
# ...           ...                   ...                            ...
# 10733  csid_10734             23.672615                       6.701514
# 10734  csid_10735             25.673028                       6.497796
# 10735  csid_10736             31.676844                       7.799880
# 10736  csid_10737             28.441780                       5.588302
# 10737  csid_10738             20.663035                       4.478301
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0               -0.070203            -0.139541                  0.436956
# 1                0.153298            -0.102726                  0.380340
# 2                0.106709             0.262834                  0.417648
# 3               -0.020226            -0.100526                  0.778130
# 4                0.187178             0.172891                  0.162067
# ...                   ...                  ...                       ...
# 10733            0.092879            -0.017332                  1.210397
# 10734            0.050216            -0.047211                  0.725230
# 10735            0.062961            -0.032765                  0.318118
# 10736           -0.093931             0.081586                  0.132177
# 10737            0.253165             0.381349                  0.504904
#
#        customer_product_variation_score  customer_order_score  \
# 0                              4.705761              2.537985
# 1                              4.205138              4.193444
# 2                              4.479070              3.878971
# 3                              5.055535              2.708940
# 4                              3.445247              3.677360
# ...                                 ...                   ...
# 10733                          7.003663              3.027084
# 10734                          5.407507              3.104172
# 10735                          5.598486              2.403051
# 10736                          3.616492              4.972243
# 10737                          4.181092              4.469215
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     7.959503                       C   F                  0
# 1                    17.517381                       C   A                  0
# 2                    12.595155                       C  BA                  0
# 3                     4.795073                      AA   F                  0
# 4                    56.636326                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 1.952911                       C  BA                  0
# 10734                 5.124286                       C  BA                  0
# 10735                21.864188                       A  BA                  0
# 10736                86.969977                       B  AA                  0
# 10737                27.770899                       B   A                  0
#
# [10738 rows x 12 columns]

# %%
f"There are {df.shape[0]} rows and {df.shape[1]} columns"
# Out:
# 'There are 10738 rows and 12 columns'

# %%
f"The size is {df.size}"
# Out:
# 'The size is 128856'

# %%
for col in df.columns:
    print(f"Column {col} type is {df.dtypes[col]}")
# Out:
# Column customer_id type is object
# Column customer_visit_score type is float64
# Column customer_product_search_score type is float64
# Column customer_ctr_score type is float64
# Column customer_stay_score type is float64
# Column customer_frequency_score type is float64
# Column customer_product_variation_score type is float64
# Column customer_order_score type is float64
# Column customer_affinity_score type is float64
# Column customer_active_segment type is object
# Column X1 type is object
# Column customer_category type is int64

# %% [markdown]
# #                                        Data Visualization

# %%
for col in df.columns[1:8]:
    df[col] = df[col].fillna(df[col].mean())
for col in df.columns[9:12]:
    df[col] = df[col].fillna(np.random.choice(df[col].unique()))

# %%
fig, axs = plt.subplots(1, 3, figsize=(25,  5))
for i in range (3):
    dct = dict(df[df.columns[9:12][i]].value_counts())
    axs[i].set_title(f"{df.columns[i+9]}")
    axs[i].bar(dct.keys(), dct.values())

# %%
data = list(df.columns[1:9])
fig = plt.figure(figsize =(4, 6)) 
plt.boxplot(df[data])
plt.title("Box plot")
plt.show()

# %%
fig, ax = plt.subplots()

ax.violinplot(df[df.columns[1:9]])
ax.set_title('Violin Plot')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,  5))
for i in range(3):
    axs[i].set_title(df.columns[i+9])
    axs[i].hist(df[df.columns[i+9]])
plt.show()

# %%
df.mean()
# Out:
# customer_visit_score                19.060941
# customer_product_search_score        5.274847
# customer_ctr_score                   0.175912
# customer_stay_score                  0.374230
# customer_frequency_score             2.376895
# customer_product_variation_score     5.788180
# customer_order_score                 3.150071
# customer_affinity_score             17.061836
# customer_category                    0.120600
# dtype: float64

# %%
df.std()
# Out:
# customer_visit_score                 7.419609
# customer_product_search_score        1.878873
# customer_ctr_score                   0.372829
# customer_stay_score                  1.219923
# customer_frequency_score             5.601911
# customer_product_variation_score     2.525881
# customer_order_score                 1.032228
# customer_affinity_score             18.762693
# customer_category                    0.325677
# dtype: float64

# %%
df.corr()
# Out:
#                                   customer_visit_score  \
# customer_visit_score                          1.000000
# customer_product_search_score                 0.273938
# customer_ctr_score                           -0.569430
# customer_stay_score                          -0.473136
# customer_frequency_score                     -0.209270
# customer_product_variation_score             -0.219643
# customer_order_score                          0.169942
# customer_affinity_score                       0.118925
# customer_category                            -0.449654
#
#                                   customer_product_search_score  \
# customer_visit_score                                   0.273938
# customer_product_search_score                          1.000000
# customer_ctr_score                                    -0.415767
# customer_stay_score                                   -0.413973
# customer_frequency_score                              -0.022998
# customer_product_variation_score                      -0.066089
# customer_order_score                                   0.050910
# customer_affinity_score                                0.044084
# customer_category                                     -0.300481
#
#                                   customer_ctr_score  customer_stay_score  \
# customer_visit_score                       -0.569430            -0.473136
# customer_product_search_score              -0.415767            -0.413973
# customer_ctr_score                          1.000000             0.907440
# customer_stay_score                         0.907440             1.000000
# customer_frequency_score                    0.419461             0.400005
# customer_product_variation_score            0.447366             0.405522
# customer_order_score                       -0.341678            -0.310364
# customer_affinity_score                    -0.232876            -0.210393
# customer_category                           0.794445             0.678073
#
#                                   customer_frequency_score  \
# customer_visit_score                             -0.209270
# customer_product_search_score                    -0.022998
# customer_ctr_score                                0.419461
# customer_stay_score                               0.400005
# customer_frequency_score                          1.000000
# customer_product_variation_score                  0.702195
# customer_order_score                             -0.532395
# customer_affinity_score                          -0.326201
# customer_category                                 0.389465
#
#                                   customer_product_variation_score  \
# customer_visit_score                                     -0.219643
# customer_product_search_score                            -0.066089
# customer_ctr_score                                        0.447366
# customer_stay_score                                       0.405522
# customer_frequency_score                                  0.702195
# customer_product_variation_score                          1.000000
# customer_order_score                                     -0.691413
# customer_affinity_score                                  -0.525248
# customer_category                                         0.492824
#
#                                   customer_order_score  \
# customer_visit_score                          0.169942
# customer_product_search_score                 0.050910
# customer_ctr_score                           -0.341678
# customer_stay_score                          -0.310364
# customer_frequency_score                     -0.532395
# customer_product_variation_score             -0.691413
# customer_order_score                          1.000000
# customer_affinity_score                       0.762481
# customer_category                            -0.384345
#
#                                   customer_affinity_score  customer_category
# customer_visit_score                             0.118925          -0.449654
# customer_product_search_score                    0.044084          -0.300481
# customer_ctr_score                              -0.232876           0.794445
# customer_stay_score                             -0.210393           0.678073
# customer_frequency_score                        -0.326201           0.389465
# customer_product_variation_score                -0.525248           0.492824
# customer_order_score                             0.762481          -0.384345
# customer_affinity_score                          1.000000          -0.274105
# customer_category                               -0.274105           1.000000

# %%
for i in range(3):
    print(df[df.columns[9+i]].value_counts())
# Out:
# C     4919
# B     4430
# D      536
# AA     441
# A      412
# Name: customer_active_segment, dtype: int64
# BA    4548
# A     2268
# F     2235
# AA    1611
# E       76
# Name: X1, dtype: int64
# 0    9443
# 1    1295
# Name: customer_category, dtype: int64

# %%
df1 = df[df.columns[1:9]]
new_df=(df1-df1.min())/(df1.max()-df1.min())
data = [df1, new_df]
new_df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10736              0.596367                       0.342273
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score
# 0                     0.033916
# 1                     0.072295
# 2                     0.052530
# 3                     0.021209
# 4                     0.229374
# ...                        ...
# 10733                 0.009797
# 10734                 0.022531
# 10735                 0.089749
# 10736                 0.351176
# 10737                 0.113467
#
# [10738 rows x 8 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize = (15,10))
count=0
names = ["Before normalization","After Normalization"]
for i in range(2):
    axes[i].set_title(names[i])
    axes[i].boxplot(data[count])
    count=+1

# %%
corrMx = df.corr()
plt.figure(figsize = (10,8))
sn.heatmap(corrMx, annot=True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df[df.columns[9:12]] = df[df.columns[9:12]].apply(lambda col: 
le.fit_transform(col))
df = pd.concat([new_df ,df[df.columns[9:12]]], axis = 1)
df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10736              0.596367                       0.342273
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   4                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   4                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10735                 0.089749                        0   2                  0
# 10736                 0.351176                        2   1                  0
# 10737                 0.113467                        2   0                  0
#
# [10738 rows x 11 columns]

# %%
from scipy import stats
z_scores = stats.zscore(df[df.columns[0:8]])
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
new_df = df[filtered_entries]
new_df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10732              0.301578                       0.327601
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10732            0.183398             0.022250                  0.004592
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10732                          0.113201              0.380645
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   4                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   4                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10732                 0.058437                        3   0                  0
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10735                 0.089749                        0   2                  0
# 10737                 0.113467                        2   0                  0
#
# [9650 rows x 11 columns]

# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X = new_df[new_df.columns[:-1]]
y = new_df[new_df.columns[-1]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
regr=RandomForestClassifier()
regr.fit(X_train,y_train)
y_pred=regr.predict(X_test)
print("Precision is",metrics.precision_score(y_test, y_pred))
print("Recall is",metrics.recall_score(y_test, y_pred))
print("Accuracy is",metrics.accuracy_score(y_test, y_pred))
# Out:
# Precision is 0.875
# Recall is 0.7664233576642335
# Accuracy is 0.9756476683937824

# %% [markdown]
# ## RandomizedSearchCV()

# %%
params = {'n_estimators':[10, 70, 100, 150], 
          'max_features': [2,4,6],          'max_depth': [None, 6, 9], 
          'min_samples_split':[2,5,10],  
          'min_samples_leaf': [1,4,8]}
rnd_search = RandomizedSearchCV(RandomForestClassifier(), params, n_iter =3, cv=9)
rnd_search.fit(X,y)
# Out:
# RandomizedSearchCV(cv=9, estimator=RandomForestClassifier(), n_iter=3,
#                    param_distributions={'max_depth': [None, 6, 9],
#                                         'max_features': [2, 4, 6],
#                                         'min_samples_leaf': [1, 4, 8],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [10, 70, 100, 150]})

# %%
print("The best accuracy applying randomized search is:",rnd_search.best_score_)
print("The best parameters from the chosen",rnd_search.best_params_)
# Out:
# The best accuracy applying randomized search is: 0.9760630097415997
# The best parameters from the chosen {'n_estimators': 150, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 2, 'max_depth': None}

# %% [markdown]
# # Feature selection

# %%
# since we have already  built heat map, we can try to pick best features manually by choosing columns from last row 
# with values greater than 0.5
X2 = new_df[new_df.columns[2:4]]
y2 = new_df[new_df.columns[-1]]
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2)
regr2=RandomForestClassifier()
regr2.fit(X2_train,y2_train)
y2_pred=regr2.predict(X2_test)

print("Accuracy after using heatmap is",metrics.accuracy_score(y2_test, y2_pred))
print("Previous accuracy is",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy after using heatmap is 0.9761658031088083
# Previous accuracy is 0.9756476683937824

# %%
# Using sklearn library
from sklearn.feature_selection import SelectFromModel
sel = SelectFromModel(RandomForestClassifier())
sel.fit(X_train, y_train)
print ("The chosen features are ", X_train.columns[(sel.get_support())])
# Out:
# The chosen features are  Index(['customer_ctr_score', 'customer_stay_score'], dtype='object')

# %%
new_reg = RandomForestClassifier()
new_reg.fit(X_train, y_train)
new_y_pred = reg.predict(X_test)
print("New accuracy: ", metrics.accuracy_score(y_test, new_y_pred))
print("Previous accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# New accuracy:  0.994300518134715
# Previous accuracy:  0.9756476683937824
