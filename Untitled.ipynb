# %%
import pandas
import matplotlib.pyplot as plt
import seaborn
from sklearn.preprocessing import LabelEncoder
from scipy import stats
plt.style.use("dark_background")
df = pandas.read_csv("train.csv")
df.drop("customer_id", inplace=True, axis=1)
df = df.dropna()
df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                 13.168425                       9.447662
# 1                 17.092979                       7.329056
# 2                 17.505334                       5.143676
# 3                 31.423381                       4.917740
# 4                 11.909502                       4.237073
# ...                     ...                            ...
# 10733             23.672615                       6.701514
# 10734             25.673028                       6.497796
# 10735             31.676844                       7.799880
# 10736             28.441780                       5.588302
# 10737             20.663035                       4.478301
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0               -0.070203            -0.139541                  0.436956
# 1                0.153298            -0.102726                  0.380340
# 2                0.106709             0.262834                  0.417648
# 3               -0.020226            -0.100526                  0.778130
# 4                0.187178             0.172891                  0.162067
# ...                   ...                  ...                       ...
# 10733            0.092879            -0.017332                  1.210397
# 10734            0.050216            -0.047211                  0.725230
# 10735            0.062961            -0.032765                  0.318118
# 10736           -0.093931             0.081586                  0.132177
# 10737            0.253165             0.381349                  0.504904
#
#        customer_product_variation_score  customer_order_score  \
# 0                              4.705761              2.537985
# 1                              4.205138              4.193444
# 2                              4.479070              3.878971
# 3                              5.055535              2.708940
# 4                              3.445247              3.677360
# ...                                 ...                   ...
# 10733                          7.003663              3.027084
# 10734                          5.407507              3.104172
# 10735                          5.598486              2.403051
# 10736                          3.616492              4.972243
# 10737                          4.181092              4.469215
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     7.959503                       C   F                  0
# 1                    17.517381                       C   A                  0
# 2                    12.595155                       C  BA                  0
# 3                     4.795073                      AA   F                  0
# 4                    56.636326                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 1.952911                       C  BA                  0
# 10734                 5.124286                       C  BA                  0
# 10735                21.864188                       A  BA                  0
# 10736                86.969977                       B  AA                  0
# 10737                27.770899                       B   A                  0
#
# [10491 rows x 11 columns]

# %%
plt.rcParams["figure.figsize"] = [10/1.2, 8/1.2]
#plt.rcParams["figure.figsize"] = [20, 20]

# %%
print("size: ", df.size, "\n")
print("shape: ", df.shape, "\n")
print("columns: ", list(df.columns), "\n")
print("type of each column:\n", df.dtypes)
# Out:
# size:  118118
#
# shape:  (10738, 11)
#
# columns:  ['customer_visit_score', 'customer_product_search_score', 'customer_ctr_score', 'customer_stay_score', 'customer_frequency_score', 'customer_product_variation_score', 'customer_order_score', 'customer_affinity_score', 'customer_active_segment', 'X1', 'customer_category']
#
# type of each column:
#  customer_visit_score                float64
# customer_product_search_score       float64
# customer_ctr_score                  float64
# customer_stay_score                 float64
# customer_frequency_score            float64
# customer_product_variation_score    float64
# customer_order_score                float64
# customer_affinity_score             float64
# customer_active_segment              object
# X1                                    int32
# customer_category                     int64
# dtype: object

# %%
plt.title("customer_visit_score")
plt.boxplot(df.customer_visit_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x230026c7948>,
#   <matplotlib.lines.Line2D at 0x23005bae2c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x23005bae1c8>,
#   <matplotlib.lines.Line2D at 0x23005afc808>],
#  'boxes': [<matplotlib.lines.Line2D at 0x23005bdab88>],
#  'medians': [<matplotlib.lines.Line2D at 0x23005b11048>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23005b29308>],
#  'means': []}

# %%
plt.title("customer_product_search_score")
plt.boxplot(df.customer_product_search_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x230057f1a48>,
#   <matplotlib.lines.Line2D at 0x23005804f88>],
#  'caps': [<matplotlib.lines.Line2D at 0x2300580acc8>,
#   <matplotlib.lines.Line2D at 0x2300580ad08>],
#  'boxes': [<matplotlib.lines.Line2D at 0x230057e2608>],
#  'medians': [<matplotlib.lines.Line2D at 0x23005811ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23005811b08>],
#  'means': []}

# %%
plt.title("customer_ctr_score")
plt.boxplot(df.customer_ctr_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2300585bcc8>,
#   <matplotlib.lines.Line2D at 0x23005874748>],
#  'caps': [<matplotlib.lines.Line2D at 0x23005874e08>,
#   <matplotlib.lines.Line2D at 0x23005874e48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2300584bac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2300587bc08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2300587bc48>],
#  'means': []}

# %%
plt.title("customer_stay_score")
plt.boxplot(df.customer_stay_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x230058bf088>,
#   <matplotlib.lines.Line2D at 0x230058de988>],
#  'caps': [<matplotlib.lines.Line2D at 0x230058def88>,
#   <matplotlib.lines.Line2D at 0x230058e4748>],
#  'boxes': [<matplotlib.lines.Line2D at 0x230058b6388>],
#  'medians': [<matplotlib.lines.Line2D at 0x230058e4e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x230058e4e88>],
#  'means': []}

# %%
plt.title("customer_frequency_score")
x = x[x.between(x.quantile(.15), x.quantile(.85))]
plt.boxplot(df.customer_frequency_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x230059282c8>,
#   <matplotlib.lines.Line2D at 0x23005947b08>],
#  'caps': [<matplotlib.lines.Line2D at 0x23005947b48>,
#   <matplotlib.lines.Line2D at 0x2300594e8c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x23005920888>],
#  'medians': [<matplotlib.lines.Line2D at 0x2300594efc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x230059556c8>],
#  'means': []}

# %%
plt.title("customer_product_variation_score")
plt.boxplot(df.customer_product_variation_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x230059962c8>,
#   <matplotlib.lines.Line2D at 0x230059b4dc8>],
#  'caps': [<matplotlib.lines.Line2D at 0x230059b4e08>,
#   <matplotlib.lines.Line2D at 0x230059bab88>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2300598c888>],
#  'medians': [<matplotlib.lines.Line2D at 0x230059babc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x230059c0888>],
#  'means': []}

# %%
plt.title("customer_order_score")
plt.boxplot(df.customer_order_score.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23005a00348>,
#   <matplotlib.lines.Line2D at 0x23005a20f48>],
#  'caps': [<matplotlib.lines.Line2D at 0x23005a20f88>,
#   <matplotlib.lines.Line2D at 0x23005a27d08>],
#  'boxes': [<matplotlib.lines.Line2D at 0x230059f9b08>],
#  'medians': [<matplotlib.lines.Line2D at 0x23005a27d48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23005a2eb08>],
#  'means': []}

# %%
plt.title("customer_affinity_score")
plt.boxplot(df.customer_affinity_score)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2300664e508>,
#   <matplotlib.lines.Line2D at 0x2300666cf88>],
#  'caps': [<matplotlib.lines.Line2D at 0x2300666cfc8>,
#   <matplotlib.lines.Line2D at 0x23006671d48>],
#  'boxes': [<matplotlib.lines.Line2D at 0x23006649188>],
#  'medians': [<matplotlib.lines.Line2D at 0x23006671d88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23006677b48>],
#  'means': []}

# %%
cas_dict = dict(df.customer_active_segment.value_counts(sort=False))

plt.title("Customer active segment barplot")

plt.bar(cas_dict.keys(), cas_dict.values())
plt.xlabel("Classes")
plt.ylabel("Amount of people of each class")
# Out:
# Text(0, 0.5, 'Amount of people of each class')

# %%
X1_dict = dict(df.X1.value_counts(sort=False))

plt.title("X1 barplot")

plt.bar(X1_dict.keys(), X1_dict.values())
plt.xlabel("Classes")
plt.ylabel("Amount of people of each class")
# Out:
# Text(0, 0.5, 'Amount of people of each class')

# %%
#mean
df.mean()
# Out:
# customer_visit_score                0.395654
# customer_product_search_score       0.323615
# customer_ctr_score                  0.224294
# customer_stay_score                 0.055177
# customer_frequency_score            0.044844
# customer_product_variation_score    0.189816
# customer_order_score                0.319328
# customer_affinity_score             0.070465
# X1                                  1.861240
# customer_category                   0.120600
# dtype: float64

# %%
#Standart deviation
df.std()
# Out:
# customer_visit_score                0.158750
# customer_product_search_score       0.112056
# customer_ctr_score                  0.115518
# customer_stay_score                 0.080585
# customer_frequency_score            0.106975
# customer_product_variation_score    0.158296
# customer_order_score                0.118647
# customer_affinity_score             0.075340
# X1                                  1.358838
# customer_category                   0.325677
# dtype: float64

# %%
#correlation matrix
df.corr()
# Out:
#                                   customer_visit_score  \
# customer_visit_score                          1.000000
# customer_product_search_score                 0.274672
# customer_ctr_score                           -0.569430
# customer_stay_score                          -0.474176
# customer_frequency_score                     -0.209270
# customer_product_variation_score             -0.220016
# customer_order_score                          0.170497
# customer_affinity_score                       0.118925
# X1                                           -0.113234
# customer_category                            -0.449654
#
#                                   customer_product_search_score  \
# customer_visit_score                                   0.274672
# customer_product_search_score                          1.000000
# customer_ctr_score                                    -0.415910
# customer_stay_score                                   -0.414855
# customer_frequency_score                              -0.023031
# customer_product_variation_score                      -0.066274
# customer_order_score                                   0.051181
# customer_affinity_score                                0.044181
# X1                                                    -0.044450
# customer_category                                     -0.300862
#
#                                   customer_ctr_score  customer_stay_score  \
# customer_visit_score                       -0.569430            -0.474176
# customer_product_search_score              -0.415910            -0.414855
# customer_ctr_score                          1.000000             0.909248
# customer_stay_score                         0.909248             1.000000
# customer_frequency_score                    0.419461             0.400374
# customer_product_variation_score            0.448071             0.406516
# customer_order_score                       -0.342506            -0.311451
# customer_affinity_score                    -0.232876            -0.210629
# X1                                          0.224533             0.197407
# customer_category                           0.794445             0.679366
#
#                                   customer_frequency_score  \
# customer_visit_score                             -0.209270
# customer_product_search_score                    -0.023031
# customer_ctr_score                                0.419461
# customer_stay_score                               0.400374
# customer_frequency_score                          1.000000
# customer_product_variation_score                  0.702688
# customer_order_score                             -0.533142
# customer_affinity_score                          -0.326201
# X1                                                0.293218
# customer_category                                 0.389465
#
#                                   customer_product_variation_score  \
# customer_visit_score                                     -0.220016
# customer_product_search_score                            -0.066274
# customer_ctr_score                                        0.448071
# customer_stay_score                                       0.406516
# customer_frequency_score                                  0.702688
# customer_product_variation_score                          1.000000
# customer_order_score                                     -0.694476
# customer_affinity_score                                  -0.525783
# X1                                                        0.462366
# customer_category                                         0.493958
#
#                                   customer_order_score  \
# customer_visit_score                          0.170497
# customer_product_search_score                 0.051181
# customer_ctr_score                           -0.342506
# customer_stay_score                          -0.311451
# customer_frequency_score                     -0.533142
# customer_product_variation_score             -0.694476
# customer_order_score                          1.000000
# customer_affinity_score                       0.763861
# X1                                           -0.441022
# customer_category                            -0.385278
#
#                                   customer_affinity_score        X1  \
# customer_visit_score                             0.118925 -0.113234
# customer_product_search_score                    0.044181 -0.044450
# customer_ctr_score                              -0.232876  0.224533
# customer_stay_score                             -0.210629  0.197407
# customer_frequency_score                        -0.326201  0.293218
# customer_product_variation_score                -0.525783  0.462366
# customer_order_score                             0.763861 -0.441022
# customer_affinity_score                          1.000000 -0.376025
# X1                                              -0.376025  1.000000
# customer_category                               -0.274105  0.265532
#
#                                   customer_category
# customer_visit_score                      -0.449654
# customer_product_search_score             -0.300862
# customer_ctr_score                         0.794445
# customer_stay_score                        0.679366
# customer_frequency_score                   0.389465
# customer_product_variation_score           0.493958
# customer_order_score                      -0.385278
# customer_affinity_score                   -0.274105
# X1                                         0.265532
# customer_category                          1.000000

# %%
df.customer_active_segment.value_counts(sort=False)
# Out:
# A      412
# D      536
# B     4430
# C     4919
# AA     418
# Name: customer_active_segment, dtype: int64

# %%
df.X1.value_counts(sort=False)
# Out:
# 0    2268
# 1    1611
# 2    4511
# 3      76
# 4    2235
# 5      37
# Name: X1, dtype: int64

# %%
df.customer_category.value_counts(sort=False)
# Out:
# 0    9443
# 1    1295
# Name: customer_category, dtype: int64

# %%
#normalization
colums_to_normalize = ['customer_visit_score', 'customer_product_search_score', 'customer_ctr_score', 'customer_stay_score', 'customer_frequency_score', 'customer_product_variation_score', 'customer_order_score', 'customer_affinity_score']
df[colums_to_normalize] = df[colums_to_normalize].apply(lambda x: (x-x.min())/(x.max()-x.min()))
df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10736              0.596367                       0.342273
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     0.033916                       C   F                  0
# 1                     0.072295                       C   A                  0
# 2                     0.052530                       C  BA                  0
# 3                     0.021209                      AA   F                  0
# 4                     0.229374                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 0.009797                       C  BA                  0
# 10734                 0.022531                       C  BA                  0
# 10735                 0.089749                       A  BA                  0
# 10736                 0.351176                       B  AA                  0
# 10737                 0.113467                       B   A                  0
#
# [10491 rows x 11 columns]

# %%
#heatmap
seaborn.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#encoding
categorical_cols = df.columns[8:11]
le = LabelEncoder()
df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10736              0.596367                       0.342273
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   4                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   4                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10735                 0.089749                        0   2                  0
# 10736                 0.351176                        2   1                  0
# 10737                 0.113467                        2   0                  0
#
# [10491 rows x 11 columns]

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'customer_visit_score'}>,
#         <AxesSubplot:title={'center':'customer_product_search_score'}>,
#         <AxesSubplot:title={'center':'customer_ctr_score'}>],
#        [<AxesSubplot:title={'center':'customer_stay_score'}>,
#         <AxesSubplot:title={'center':'customer_frequency_score'}>,
#         <AxesSubplot:title={'center':'customer_product_variation_score'}>],
#        [<AxesSubplot:title={'center':'customer_order_score'}>,
#         <AxesSubplot:title={'center':'customer_affinity_score'}>,
#         <AxesSubplot:title={'center':'customer_active_segment'}>],
#        [<AxesSubplot:title={'center':'X1'}>,
#         <AxesSubplot:title={'center':'customer_category'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
#boxplots
df1=df[['customer_visit_score', 'customer_product_search_score', 'customer_ctr_score', 'customer_stay_score', 'customer_frequency_score', 'customer_product_variation_score', 'customer_order_score', 'customer_affinity_score']]
df1.boxplot(grid=False)
# Out:
# <AxesSubplot:>

# %%
#resolving outliers
z_scores = stats.zscore(df)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df_ro = df[filtered_entries]
df_ro
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10731              0.610325                       0.390081
# 10732              0.301578                       0.327601
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10731            0.153900             0.025240                  0.007759
# 10732            0.183398             0.022250                  0.004592
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10731                          0.127516              0.215561
# 10732                          0.113201              0.380645
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   4                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   4                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10731                 0.027057                        2   2                  0
# 10732                 0.058437                        3   0                  0
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10737                 0.113467                        2   0                  0
#
# [9056 rows x 11 columns]

# %%
from sklearn.svm import LinearSVC
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
x = df[['customer_visit_score', 'customer_product_search_score', 'customer_ctr_score', 'customer_stay_score', 'customer_frequency_score', 'customer_product_variation_score', 'customer_order_score', 'customer_affinity_score','customer_active_segment','X1']]
y = df['customer_category']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
model = LinearSVC()
model.fit(x_train, y_train)
y_predicted = model.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_predicted))
print("Precision:", precision_score(y_test, y_predicted))
print("Recall:", recall_score(y_test, y_predicted))
# Out:
# Accuracy: 0.9710927573062261
# Precision: 0.9703947368421053
# Recall: 0.7824933687002652

# %%
from sklearn.svm import LinearSVC
from sklearn import metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
x = df[['customer_visit_score', 'customer_product_search_score', 'customer_ctr_score', 'customer_stay_score', 'customer_frequency_score', 'customer_product_variation_score', 'customer_order_score', 'customer_affinity_score','customer_active_segment','X1']]
y = df['customer_category']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
model = RandomForestClassifier()
model.fit(x_train, y_train)
y_predicted = model.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_predicted))
print("Precision:", precision_score(y_test, y_predicted))
print("Recall:", recall_score(y_test, y_predicted))
# Out:
# Accuracy: 0.9758576874205845
# Precision: 0.9429429429429429
# Recall: 0.8463611859838275
