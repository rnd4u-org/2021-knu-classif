# %% [markdown]
# #       2021-Jan-26 (Tue) – Dataset Exploring and Environment setup

# %% [markdown]
# ### Import pandas library and find out info about data frame from "train.csv"

# %%
import pandas

df = pandas.read_csv("train.csv")
print("size: ", df.size, "\n")
print("shape: ", df.shape, "\n")
print("columns: ", list(df.columns), "\n")
print("type of each column:\n", df.dtypes)
# Out:
# size:  128856
#
# shape:  (10738, 12)
#
# columns:  ['customer_id', 'customer_visit_score', 'customer_product_search_score', 'customer_ctr_score', 'customer_stay_score', 'customer_frequency_score', 'customer_product_variation_score', 'customer_order_score', 'customer_affinity_score', 'customer_active_segment', 'X1', 'customer_category']
#
# type of each column:
#  customer_id                          object
# customer_visit_score                float64
# customer_product_search_score       float64
# customer_ctr_score                  float64
# customer_stay_score                 float64
# customer_frequency_score            float64
# customer_product_variation_score    float64
# customer_order_score                float64
# customer_affinity_score             float64
# customer_active_segment              object
# X1                                   object
# customer_category                     int64
# dtype: object

# %% [markdown]
# ### Print out our data frame

# %%
df
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1             13.168425                       9.447662
# 1          csid_2             17.092979                       7.329056
# 2          csid_3             17.505334                       5.143676
# 3          csid_4             31.423381                       4.917740
# 4          csid_5             11.909502                       4.237073
# ...           ...                   ...                            ...
# 10733  csid_10734             23.672615                       6.701514
# 10734  csid_10735             25.673028                       6.497796
# 10735  csid_10736             31.676844                       7.799880
# 10736  csid_10737             28.441780                       5.588302
# 10737  csid_10738             20.663035                       4.478301
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0               -0.070203            -0.139541                  0.436956
# 1                0.153298            -0.102726                  0.380340
# 2                0.106709             0.262834                  0.417648
# 3               -0.020226            -0.100526                  0.778130
# 4                0.187178             0.172891                  0.162067
# ...                   ...                  ...                       ...
# 10733            0.092879            -0.017332                  1.210397
# 10734            0.050216            -0.047211                  0.725230
# 10735            0.062961            -0.032765                  0.318118
# 10736           -0.093931             0.081586                  0.132177
# 10737            0.253165             0.381349                  0.504904
#
#        customer_product_variation_score  customer_order_score  \
# 0                              4.705761              2.537985
# 1                              4.205138              4.193444
# 2                              4.479070              3.878971
# 3                              5.055535              2.708940
# 4                              3.445247              3.677360
# ...                                 ...                   ...
# 10733                          7.003663              3.027084
# 10734                          5.407507              3.104172
# 10735                          5.598486              2.403051
# 10736                          3.616492              4.972243
# 10737                          4.181092              4.469215
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     7.959503                       C   F                  0
# 1                    17.517381                       C   A                  0
# 2                    12.595155                       C  BA                  0
# 3                     4.795073                      AA   F                  0
# 4                    56.636326                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 1.952911                       C  BA                  0
# 10734                 5.124286                       C  BA                  0
# 10735                21.864188                       A  BA                  0
# 10736                86.969977                       B  AA                  0
# 10737                27.770899                       B   A                  0
#
# [10738 rows x 12 columns]

# %% [markdown]
# # 2021-Jan-27-28 (Wed-Thu) – Data Visualization

# %% [markdown]
# ### Remove all NaNs

# %%
import numpy as np

df = df.dropna()
df
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1             13.168425                       9.447662
# 1          csid_2             17.092979                       7.329056
# 2          csid_3             17.505334                       5.143676
# 3          csid_4             31.423381                       4.917740
# 4          csid_5             11.909502                       4.237073
# ...           ...                   ...                            ...
# 10733  csid_10734             23.672615                       6.701514
# 10734  csid_10735             25.673028                       6.497796
# 10735  csid_10736             31.676844                       7.799880
# 10736  csid_10737             28.441780                       5.588302
# 10737  csid_10738             20.663035                       4.478301
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0               -0.070203            -0.139541                  0.436956
# 1                0.153298            -0.102726                  0.380340
# 2                0.106709             0.262834                  0.417648
# 3               -0.020226            -0.100526                  0.778130
# 4                0.187178             0.172891                  0.162067
# ...                   ...                  ...                       ...
# 10733            0.092879            -0.017332                  1.210397
# 10734            0.050216            -0.047211                  0.725230
# 10735            0.062961            -0.032765                  0.318118
# 10736           -0.093931             0.081586                  0.132177
# 10737            0.253165             0.381349                  0.504904
#
#        customer_product_variation_score  customer_order_score  \
# 0                              4.705761              2.537985
# 1                              4.205138              4.193444
# 2                              4.479070              3.878971
# 3                              5.055535              2.708940
# 4                              3.445247              3.677360
# ...                                 ...                   ...
# 10733                          7.003663              3.027084
# 10734                          5.407507              3.104172
# 10735                          5.598486              2.403051
# 10736                          3.616492              4.972243
# 10737                          4.181092              4.469215
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     7.959503                       C   F                  0
# 1                    17.517381                       C   A                  0
# 2                    12.595155                       C  BA                  0
# 3                     4.795073                      AA   F                  0
# 4                    56.636326                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 1.952911                       C  BA                  0
# 10734                 5.124286                       C  BA                  0
# 10735                21.864188                       A  BA                  0
# 10736                86.969977                       B  AA                  0
# 10737                27.770899                       B   A                  0
#
# [10491 rows x 12 columns]

# %% [markdown]
# ### Import matplotlib and for every categorical variable build a barplot

# %%
import matplotlib.pyplot as plt

columns = df.columns[-3::]

fig, axs = plt.subplots(1, 3, figsize=(20,  5))

for i in range(3):
    value_dict = dict(df[columns[i]].value_counts(sort=False))
    axs[i].set_title(f"{columns[i]} barplot")
    axs[i].bar(value_dict.keys(), value_dict.values())



plt.show()

# %%
# df[df.isnull().values == True]

# %% [markdown]
# ### For every numerical value build boxplot

# %%
col_names = list(df.columns[1:-3])

plt.boxplot(df[col_names])

plt.show()

# %% [markdown]
# ### Plot histograms

# %%
fig, axs = plt.subplots(2, 4, figsize=(20,  10))

col_ind = 0

for i in range(2):
    for j in range(4):
        axs[i, j].set_title(f"{col_names[col_ind]} histogram")
        axs[i, j].hist(df[col_names[col_ind]])
        col_ind += 1

plt.show()

# %% [markdown]
# ### Plot pies

# %%
fig, axs = plt.subplots(1, 3, figsize=(15,  7))

for i in range(3):
    value_dict = dict(df[columns[i]].value_counts(sort=False))
    axs[i].set_title(f"{columns[i]} pie")
    axs[i].pie(value_dict.values(), labels=value_dict.keys())

plt.show()

# %% [markdown]
# ### Normallize data where possible

# %%
normalized_df = df.copy()
normalized_df[col_names] = normalized_df[col_names].apply(lambda x: (x-x.min())/(x.max()-x.min()))
normalized_df
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1              0.269578                       0.571994
# 1          csid_2              0.353548                       0.445888
# 2          csid_3              0.362370                       0.315807
# 3          csid_4              0.660161                       0.302359
# 4          csid_5              0.242642                       0.261843
# ...           ...                   ...                            ...
# 10733  csid_10734              0.494325                       0.408534
# 10734  csid_10735              0.537126                       0.396409
# 10735  csid_10736              0.665584                       0.473913
# 10736  csid_10737              0.596367                       0.342273
# 10737  csid_10738              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     0.033916                       C   F                  0
# 1                     0.072295                       C   A                  0
# 2                     0.052530                       C  BA                  0
# 3                     0.021209                      AA   F                  0
# 4                     0.229374                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 0.009797                       C  BA                  0
# 10734                 0.022531                       C  BA                  0
# 10735                 0.089749                       A  BA                  0
# 10736                 0.351176                       B  AA                  0
# 10737                 0.113467                       B   A                  0
#
# [10491 rows x 12 columns]

# %% [markdown]
# ### Print out boxplot after and before data normalization

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,  7))

axs[0].boxplot(normalized_df[col_names])
axs[0].set_xticklabels(col_names, rotation=90)

axs[1].boxplot(df[col_names])
axs[1].set_xticklabels(col_names, rotation=90)

plt.show()

# %% [markdown]
# ### Print histograms after and before data normalization (only numbers on x axis change )

# %%
fig, axs = plt.subplots(4, 4, figsize=(20,  20))

col_ind = 0

for i in range(2):
    for j in range(4):
        axs[i, j].set_title(f"{col_names[col_ind]} histogram")
        axs[i, j].hist(normalized_df[col_names[col_ind]])
        col_ind += 1
        
col_ind = 0

for i in range(2, 4):
    for j in range(4):
        axs[i, j].set_title(f"{col_names[col_ind]} histogram")
        axs[i, j].hist(df[col_names[col_ind]])
        col_ind += 1

plt.show()

# %% [markdown]
# ### Calculate statistics (mean, standard deviation, correlation matrix, frequency) where possible

# %%
for col in normalized_df.columns[1:-3]:
    print("mean for", col, ": ", normalized_df[col].mean())

print()

for col in normalized_df.columns[1:-3]:
    print("standard diviation for", col, ": ", normalized_df[col].std())

print()

for col in normalized_df.columns[-3::]:
    print("frequency for ", col, ":")
    print(normalized_df[col].value_counts())
    print()

print()
# Out:
# mean for customer_visit_score :  0.3953198437459999
# mean for customer_product_search_score :  0.3236891439518074
# mean for customer_ctr_score :  0.2244854391127744
# mean for customer_stay_score :  0.05528696496127666
# mean for customer_frequency_score :  0.04509750422413934
# mean for customer_product_variation_score :  0.19016027478569386
# mean for customer_order_score :  0.31932630034532966
# mean for customer_affinity_score :  0.07043302049636609
#
# standard diviation for customer_visit_score :  0.15856010650078994
# standard diviation for customer_product_search_score :  0.11209726030155039
# standard diviation for customer_ctr_score :  0.11592406772567672
# standard diviation for customer_stay_score :  0.0809367408095353
# standard diviation for customer_frequency_score :  0.10744487227300126
# standard diviation for customer_product_variation_score :  0.15861824907007455
# standard diviation for customer_order_score :  0.11884934648913083
# standard diviation for customer_affinity_score :  0.0756323296883505
#
# frequency for  customer_active_segment :
# C     4815
# B     4350
# D      522
# AA     402
# A      402
# Name: customer_active_segment, dtype: int64
#
# frequency for  X1 :
# BA    4427
# A     2215
# F     2200
# AA    1574
# E       75
# Name: X1, dtype: int64
#
# frequency for  customer_category :
# 0    9222
# 1    1269
# Name: customer_category, dtype: int64

# %%
# correlation matrix
corr = normalized_df.corr()
corr
# Out:
#                                   customer_visit_score  \
# customer_visit_score                          1.000000
# customer_product_search_score                 0.275355
# customer_ctr_score                           -0.569854
# customer_stay_score                          -0.475129
# customer_frequency_score                     -0.211943
# customer_product_variation_score             -0.221562
# customer_order_score                          0.171515
# customer_affinity_score                       0.118932
# customer_category                            -0.449501
#
#                                   customer_product_search_score  \
# customer_visit_score                                   0.275355
# customer_product_search_score                          1.000000
# customer_ctr_score                                    -0.415561
# customer_stay_score                                   -0.414471
# customer_frequency_score                              -0.022742
# customer_product_variation_score                      -0.065763
# customer_order_score                                   0.049241
# customer_affinity_score                                0.043319
# customer_category                                     -0.300151
#
#                                   customer_ctr_score  customer_stay_score  \
# customer_visit_score                       -0.569854            -0.475129
# customer_product_search_score              -0.415561            -0.414471
# customer_ctr_score                          1.000000             0.909241
# customer_stay_score                         0.909241             1.000000
# customer_frequency_score                    0.421412             0.402413
# customer_product_variation_score            0.448735             0.407295
# customer_order_score                       -0.343172            -0.312002
# customer_affinity_score                    -0.232725            -0.210212
# customer_category                           0.793852             0.678401
#
#                                   customer_frequency_score  \
# customer_visit_score                             -0.211943
# customer_product_search_score                    -0.022742
# customer_ctr_score                                0.421412
# customer_stay_score                               0.402413
# customer_frequency_score                          1.000000
# customer_product_variation_score                  0.701687
# customer_order_score                             -0.533257
# customer_affinity_score                          -0.325495
# customer_category                                 0.390522
#
#                                   customer_product_variation_score  \
# customer_visit_score                                     -0.221562
# customer_product_search_score                            -0.065763
# customer_ctr_score                                        0.448735
# customer_stay_score                                       0.407295
# customer_frequency_score                                  0.701687
# customer_product_variation_score                          1.000000
# customer_order_score                                     -0.694472
# customer_affinity_score                                  -0.524955
# customer_category                                         0.493653
#
#                                   customer_order_score  \
# customer_visit_score                          0.171515
# customer_product_search_score                 0.049241
# customer_ctr_score                           -0.343172
# customer_stay_score                          -0.312002
# customer_frequency_score                     -0.533257
# customer_product_variation_score             -0.694472
# customer_order_score                          1.000000
# customer_affinity_score                       0.764188
# customer_category                            -0.385063
#
#                                   customer_affinity_score  customer_category
# customer_visit_score                             0.118932          -0.449501
# customer_product_search_score                    0.043319          -0.300151
# customer_ctr_score                              -0.232725           0.793852
# customer_stay_score                             -0.210212           0.678401
# customer_frequency_score                        -0.325495           0.390522
# customer_product_variation_score                -0.524955           0.493653
# customer_order_score                             0.764188          -0.385063
# customer_affinity_score                          1.000000          -0.272859
# customer_category                               -0.272859           1.000000

# %% [markdown]
# ### Plot a heat map for correlation matrix

# %%
plt.figure(figsize=(7, 7))
plt.pcolor(corr)
plt.yticks(ticks=range(9), labels=col_names + ["customer_category"], fontsize=12)
plt.xticks(ticks=range(9), labels=col_names + ["customer_category"], rotation=90, fontsize=12)
plt.show()

# %% [markdown]
# ## Encode categorical features so that i can use it in ML and drop first column as it doesnt tell us anything

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = normalized_df.columns[-3::]
le = LabelEncoder()
# apply le on categorical feature columns
normalized_df[categorical_cols] = normalized_df[categorical_cols].apply(lambda col: le.fit_transform(col))
main_df = normalized_df[normalized_df.columns[1::]]
main_df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10736              0.596367                       0.342273
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   4                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   4                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10735                 0.089749                        0   2                  0
# 10736                 0.351176                        2   1                  0
# 10737                 0.113467                        2   0                  0
#
# [10491 rows x 11 columns]

# %% [markdown]
# # 2021-Jan-29 (Fri) – Random Forest

# %% [markdown]
# ### Removing outliers from our dataframe

# %%
from scipy import stats

ml_df = main_df.copy()
num_df = ml_df[ml_df.columns[:-3]]

num_df = num_df[(np.abs(stats.zscore(num_df)) < 3).all(axis=1)]
indexes = list(num_df.index)

ml_df = ml_df.loc[indexes]
ml_df[ml_df.columns[:-3]] = num_df

ml_df
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10732              0.301578                       0.327601
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10732            0.183398             0.022250                  0.004592
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10732                          0.113201              0.380645
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   4                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   4                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10732                 0.058437                        3   0                  0
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10735                 0.089749                        0   2                  0
# 10737                 0.113467                        2   0                  0
#
# [9430 rows x 11 columns]

# %% [markdown]
# ### Split daraframe on train and test datasets

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X = ml_df[ml_df.columns[:-1]]
Y = ml_df['customer_category']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

randforest = RandomForestClassifier(n_estimators=200)
randforest.fit(X_train, y_train)

rf_pred = randforest.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, rf_pred))
print("Precision:",metrics.precision_score(y_test, rf_pred))
print("Recall:",metrics.recall_score(y_test, rf_pred))
# Out:
# Accuracy: 0.9720749381406858
# Precision: 0.9239130434782609
# Recall: 0.723404255319149

# %% [markdown]
# # 2021-Feb-1 (Mon) – Feature Selection

# %% [markdown]
# ### Applying feature selection algorithms

# %%
from sklearn.feature_selection import SelectFromModel, SelectKBest, chi2

feat_sel = SelectFromModel(RandomForestClassifier())

feat_sel.fit(X_train, y_train)

selected_feat= X_train[X_train.columns[(feat_sel.get_support())]]
reg2 = RandomForestClassifier()
reg2.fit(X_train, y_train)

y2_pred = reg2.predict(X_test)

print(feat_sel.get_support())
print("New Accuracy: ", metrics.accuracy_score(y_test, y2_pred))
# Out:
# [False False  True  True False False False False False False]
# New Accuracy:  0.9720749381406858

# %% [markdown]
# # 2021-Feb-2-4 (Tue-Thu) – Model Evaluation, ROC Curve

# %% [markdown]
# ### Main calculations (roc curve, roc AUC score, cross-validation)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

randforest = RandomForestClassifier()
nearneighbor = KNeighborsClassifier(n_neighbors=6)
naivebayes = GaussianNB()
supvector = SVC(kernel="linear", probability=True)
logregression = LogisticRegression()

models = [
    ["Random Forest ", randforest],
    ["K neighbors ", nearneighbor],
    ["Naive Bayes ", naivebayes], 
    ["Support vector machine ", supvector],
    ["Regression ", logregression]
]

pred_values = []
proba_values = []
roc_auc_score_values = []
roc_curve_values = []
cross_val_scores = []

for model in models:
    print(models.index(model) * 100 // len(models), "% ...")
    model[1].fit(X_train, y_train)
    
    pred = model[1].predict(X_test)
    proba = model[1].predict_proba(X_test)[:, 1]
    auc = metrics.roc_auc_score(y_test, proba)
    pr, tpr, thresholds = metrics.roc_curve(y_test, proba)
    
    cross_score = cross_val_score(model[1], X, Y, cv=10, scoring="accuracy").mean()
    
    pred_values.append([model[0], pred])
    proba_values.append([model[0], proba])
    roc_auc_score_values.append([model[0], auc])
    roc_curve_values.append([model[0], [pr, tpr]])
    cross_val_scores.append([model[0], cross_score])
    
print("Training done")
# Out:
# 0 % ...
# 20 % ...
# 40 % ...
# 60 % ...
# 80 % ...
# Training done

# %% [markdown]
# ### Print roc "area under curve" score, cross-validation accuracies and plot roc curve

# %%
print("Accuracy for each algorithm:\n")
for value in pred_values:
    print(value[0], metrics.accuracy_score(y_test, value[1]))

print("\n")
    
print("Area under each curve after each algorithm:\n")
for value in roc_auc_score_values:
    print(*value)
    
print("\n")
    
print("Cross validation accuracy for each algorithm:\n")
for value in cross_val_scores:
    print(*value)
    
for value in roc_curve_values:
    plt.plot(value[1][0], value[1][1], marker=".", label=value[0])
    
plt.xlabel("False Positive")
plt.ylabel("True Positive")
plt.legend()
plt.show()
# Out:
# Accuracy for each algorithm:
#
# Random Forest  0.9720749381406858
# K neighbors  0.9660657476139979
# Naive Bayes  0.9388476493460587
# Support vector machine  0.9664192294096854
# Regression  0.9607635206786851
#
#
# Area under each curve after each algorithm:
#
# Random Forest  0.9330738693220033
# K neighbors  0.8797117734870978
# Naive Bayes  0.9088272445414131
# Support vector machine  0.9453009399760494
# Regression  0.9307764234977607
#
#
# Cross validation accuracy for each algorithm:
#
# Random Forest  0.9758218451749736
# K neighbors  0.968186638388123
# Naive Bayes  0.9412513255567339
# Support vector machine  0.9708377518557795
# Regression  0.9672322375397668

# %% [markdown]
# ### Finding best parametrs values for Random Forest Classifier (it showed itself  best of all)

# %%
from sklearn.model_selection import RandomizedSearchCV

# {'n_estimators', 'max_features', 'max_depth', 'min_samples_split', 'min_samples_leaf'}

randforest = RandomForestClassifier()

params = {'max_depth': [3, 5, 10, 15, None],
          'n_estimators': [10, 100, 200, 300, 400, 500],
          'max_features': [1, 2, 3, 4, 5, 6, 7, 8, 9],
          'min_samples_split': [2, 3, 4],
          'min_samples_leaf': [1, 2, 3, 4],
              }

randsearch = RandomizedSearchCV(randforest, params, random_state=0)
randsearch.fit(X, Y)
best_params = randsearch.best_params_
print(best_params)
# Out:
# {'n_estimators': 100, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 6, 'max_depth': 5}

# %% [markdown]
# ###  Use these parametrs in Random Forest

# %%
randforest_best = RandomForestClassifier(n_estimators=100,
                                         min_samples_split=3,
                                         min_samples_leaf=2,
                                         max_features=6,
                                         max_depth=5)
randforest_best.fit(X_train, y_train)

rf_b_pred = randforest_best.predict(X_test)

print("Usual Random forest: ", metrics.accuracy_score(y_test, rf_pred))
print("Random forest with best parametrs: ", metrics.accuracy_score(y_test, rf_b_pred))
# Out:
# Usual Random forest:  0.9720749381406858
# Random forest with best parametrs:  0.9724284199363733
