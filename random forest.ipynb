# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from scipy import stats
df = pd.read_csv("train.csv")

# %%
for column in df.columns: #replace NaN by random data
    df[column] = df[column].fillna(np.random.choice(df[column].unique()))
    
ncols = df.columns[1:-3]
df[ncols] = df[ncols].apply(lambda x: (x-x.min())/(x.max()-x.min())) #normalizing
norm = df
norm
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10736              0.596367                       0.342273
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10736            0.140686             0.035879                  0.001978
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10736                          0.054009              0.528128
# 10737                          0.089316              0.470487
#
#        customer_affinity_score customer_active_segment  X1  customer_category
# 0                     0.033916                       C   F                  0
# 1                     0.072295                       C   A                  0
# 2                     0.052530                       C  BA                  0
# 3                     0.021209                      AA   F                  0
# 4                     0.229374                       C  AA                  0
# ...                        ...                     ...  ..                ...
# 10733                 0.009797                       C  BA                  0
# 10734                 0.022531                       C  BA                  0
# 10735                 0.089749                       A  BA                  0
# 10736                 0.351176                       B  AA                  0
# 10737                 0.113467                       B   A                  0
#
# [10738 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder#encoding 
cols = wo.columns[8:12]
le = LabelEncoder()
wo[cols] = wo[cols].apply(lambda col: le.fit_transform(col))
wo
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 4                  0.242642                       0.261843
# ...                     ...                            ...
# 10732              0.301578                       0.327601
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10735              0.665584                       0.473913
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 4                0.227785             0.041900                  0.002549
# ...                   ...                  ...                       ...
# 10732            0.183398             0.022250                  0.004592
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10735            0.189297             0.028338                  0.005529
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 4                              0.043300              0.379749
# ...                                 ...                   ...
# 10732                          0.113201              0.380645
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10735                          0.177953              0.233728
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   3                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   3                  0
# 4                     0.229374                        3   1                  0
# ...                        ...                      ...  ..                ...
# 10732                 0.058437                        3   0                  0
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10735                 0.089749                        0   2                  0
# 10737                 0.113467                        2   0                  0
#
# [9650 rows x 11 columns]

# %%
wo = wo.copy() #remove outliers
new = wo[wo.columns[:-3]]
new = new[(np.abs(stats.zscore(new)) < 3).all(axis=1) == True]
idx = list(new.index)
wo =wo.loc[idx]
wo[wo.columns[:-3]] = new
wo
# Out:
#        customer_visit_score  customer_product_search_score  \
# 0                  0.269578                       0.571994
# 1                  0.353548                       0.445888
# 2                  0.362370                       0.315807
# 3                  0.660161                       0.302359
# 5                  0.180560                       0.429371
# ...                     ...                            ...
# 10731              0.610325                       0.390081
# 10732              0.301578                       0.327601
# 10733              0.494325                       0.408534
# 10734              0.537126                       0.396409
# 10737              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# 0                0.148038             0.021297                  0.007799
# 1                0.217287             0.023724                  0.006717
# 2                0.202852             0.047831                  0.007430
# 3                0.163523             0.023870                  0.014314
# 5                0.219849             0.033202                  0.003120
# ...                   ...                  ...                       ...
# 10731            0.153900             0.025240                  0.007759
# 10732            0.183398             0.022250                  0.004592
# 10733            0.198567             0.029356                  0.022568
# 10734            0.185348             0.027385                  0.013303
# 10737            0.248230             0.055646                  0.009096
#
#        customer_product_variation_score  customer_order_score  \
# 0                              0.122126              0.249190
# 1                              0.090820              0.438887
# 2                              0.107950              0.402852
# 3                              0.144000              0.268779
# 5                              0.091114              0.322982
# ...                                 ...                   ...
# 10731                          0.127516              0.215561
# 10732                          0.113201              0.380645
# 10733                          0.265826              0.305235
# 10734                          0.166010              0.314068
# 10737                          0.089316              0.470487
#
#        customer_affinity_score  customer_active_segment  X1  customer_category
# 0                     0.033916                        3   3                  0
# 1                     0.072295                        3   0                  0
# 2                     0.052530                        3   2                  0
# 3                     0.021209                        1   3                  0
# 5                     0.077697                        3   2                  0
# ...                        ...                      ...  ..                ...
# 10731                 0.027057                        2   2                  0
# 10732                 0.058437                        3   0                  0
# 10733                 0.009797                        3   2                  0
# 10734                 0.022531                        3   2                  0
# 10737                 0.113467                        2   0                  0
#
# [7585 rows x 11 columns]

# %%
X = wo[wo.columns[:-1]]#applying Random Forest classifier
y = wo['customer_category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
classifier = RandomForestClassifier(n_estimators=200)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
p=metrics.precision_score(y_test, y_pred,zero_division='warn')#for each class print: precision, recall, accuracy

r=metrics.recall_score(y_test, y_pred,zero_division='warn')

a=metrics.accuracy_score(y_test, y_pred)
# Out:
# c:\users\katyu\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\katyu\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Precision:")
p
# Out:
# Precision:
# 0.0

# %%
print("Recall:")
r
# Out:
# Recall:
# 0.0

# %%
print("Accuracy:")
a
# Out:
# Accuracy:
# 1.0
