# %%
import pandas

ds_train = pandas.read_csv("train.csv")
ds_train = pandas.DataFrame(ds_train)   

print("There are {} rows in ds_train.".format(ds_train.shape[0]))
print("There are {} columns in ds_train.\n".format(ds_train.shape[1]))

i = 0
for col in ds_train.columns:
    print("Column {}:".format(i))
    print("Name: {} Type: {}".format('"' + col + '",', ds_train.dtypes[i]))
    i += 1

print("Size: {}".format(ds_train.size))

ds_train
# Out:
# There are 10738 rows in ds_train.
# There are 12 columns in ds_train.
#
# Column 0:
# Name: "customer_id", Type: object
# Column 1:
# Name: "customer_visit_score", Type: float64
# Column 2:
# Name: "customer_product_search_score", Type: float64
# Column 3:
# Name: "customer_ctr_score", Type: float64
# Column 4:
# Name: "customer_stay_score", Type: float64
# Column 5:
# Name: "customer_frequency_score", Type: float64
# Column 6:
# Name: "customer_product_variation_score", Type: float64
# Column 7:
# Name: "customer_order_score", Type: float64
# Column 8:
# Name: "customer_affinity_score", Type: float64
# Column 9:
# Name: "customer_active_segment", Type: object
# Column 10:
# Name: "X1", Type: object
# Column 11:
# Name: "customer_category", Type: int64
# Size: 128856
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1             13.168425                       9.447662
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,3,figsize=(10,  5))
a=0
for i in ds_train.columns[9:12]:
    bar_dict = dict(ds_train[i].value_counts())
    ax[a].bar(bar_dict.keys(),bar_dict.values())
    ax[a].set_title(i)
    a+=1
plt.show()

# %%
ds_train.mean()
# Out:
# customer_visit_score                19.060941
# customer_product_search_score        5.274847
# customer_ctr_score                   0.175912
# customer_stay_score                  0.374230
# customer_frequency_score             2.376895
# customer_product_variation_score     5.788180
# customer_order_score                 3.150071
# customer_affinity_score             17.061836
# customer_category                    0.120600
# dtype: float64

# %%
ds_train.std()
# Out:
# customer_visit_score                 7.419609
# customer_product_search_score        1.882559
# customer_ctr_score                   0.372829
# customer_stay_score                  1.222031
# customer_frequency_score             5.601911
# customer_product_variation_score     2.531309
# customer_order_score                 1.035416
# customer_affinity_score             18.762693
# customer_category                    0.325677
# dtype: float64

# %%
ds_train.corr()
# Out:
#                                   customer_visit_score  \
# customer_visit_score                          1.000000
# customer_product_search_score                 0.274672
# customer_ctr_score                           -0.569430
# customer_stay_score                          -0.474176
# customer_frequency_score                     -0.209270
# customer_product_variation_score             -0.220016
# customer_order_score                          0.170497
# customer_affinity_score                       0.118925
# customer_category                            -0.449654
#
#                                   customer_product_search_score  \
# customer_visit_score                                   0.274672
# customer_product_search_score                          1.000000
# customer_ctr_score                                    -0.415910
# customer_stay_score                                   -0.414855
# customer_frequency_score                              -0.023031
# ...

# %%
for i in ds_train.columns[9:12]:
    print(ds_train[i].value_counts())
# Out:
# C     4919
# B     4430
# D      536
# AA     418
# A      412
# Name: customer_active_segment, dtype: int64
# BA    4511
# A     2268
# F     2235
# AA    1611
# E       76
# Name: X1, dtype: int64
# 0    9443
# 1    1295
# Name: customer_category, dtype: int64

# %%
for i in ds_train.columns[1:9]:
    plt.figure(figsize=(10, 5))
    plt.title(i)
    plt.boxplot(ds_train[i].dropna())

# %%
for i in ds_train.columns[1:9]:
    plt.figure(figsize=(10, 5))
    plt.title(i)
    plt.hist(ds_train[i].dropna())

# %%
plt.scatter(ds_train.customer_affinity_score, ds_train.customer_product_search_score)

# %%
for col in ds_train.columns: 
    ds_train[col] = ds_train[col].fillna(ds_train.mean())
    
ncol = ds_train.columns[1:-3]
ds_train[ncol] = ds_train[ncol].apply(lambda x: (x-x.min())/(x.max()-x.min()))
ds_train
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1              0.269578                       0.571994
# 1          csid_2              0.353548                       0.445888
# 2          csid_3              0.362370                       0.315807
# 3          csid_4              0.660161                       0.302359
# 4          csid_5              0.242642                       0.261843
# ...           ...                   ...                            ...
# 10733  csid_10734              0.494325                       0.408534
# 10734  csid_10735              0.537126                       0.396409
# 10735  csid_10736              0.665584                       0.473913
# 10736  csid_10737              0.596367                       0.342273
# 10737  csid_10738              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# ...

# %%
import seaborn as sn
sn.heatmap(ds_train.corr())

# %%
from sklearn.preprocessing import LabelEncoder
col = ds_train.columns[9:12]
LE = LabelEncoder()
ds_train[col] = ds_train[col].apply(lambda col: LE.fit_transform(col))
ds_train
# Out:
#       customer_id  customer_visit_score  customer_product_search_score  \
# 0          csid_1              0.269578                       0.571994
# 1          csid_2              0.353548                       0.445888
# 2          csid_3              0.362370                       0.315807
# 3          csid_4              0.660161                       0.302359
# 4          csid_5              0.242642                       0.261843
# ...           ...                   ...                            ...
# 10733  csid_10734              0.494325                       0.408534
# 10734  csid_10735              0.537126                       0.396409
# 10735  csid_10736              0.665584                       0.473913
# 10736  csid_10737              0.596367                       0.342273
# 10737  csid_10738              0.429933                       0.276202
#
#        customer_ctr_score  customer_stay_score  customer_frequency_score  \
# ...
